# %% [markdown]
# # Proyecto 2: Primera parte
# Curso Ingeniería de Características
#
#
# **Estephania Pivac Alcaraz**
#
# ---
#
# **Problema de interés:**
# Estudar la relación que existe entre la cantidad de accidentes de tránsito y la inversión a la conservación de carreteras.

# %% [markdown]
# ## EDA
# Análisis exploratiorio de datos

# %%
# Instalamos Pandas-profiling
#pip install Pandas-Profiling

# Importamos algunas librerías que vamos a necesitar
import os  # Para manejo de archivos y directorios
import urllib.request # Una forma estandard de descargar datos
# import requests # Otra forma no de las librerías de uso comun

import datetime # Fecha de descarga
import pandas as pd # Solo para ver el archivo descargado
import zipfile # Descompresión de archivos
import numpy as np
from pandas_profiling import ProfileReport

# %% [markdown]
# Abrimos los dataframe tidy que generamos en el proyecto 1.

# %%
# Generamos el dataframe de accidentes
tidy_accidentes = pd.read_csv("tidy_accidentes.csv", index_col=False)

# Convertimos cada variable de acuerdo a su tipo
# Categoricas
tidy_accidentes = tidy_accidentes.astype({'TIPACCID':'category', 'CAUSAACCI':'category', 'CAPAROD':'category', 'CLASACC':'category', 'EDAD':'category'})

# Fechas
#tidy_accidentes['FECHA'] = pd.to_datetime(tidy_accidentes['FECHA'], format='%m/%d/%Y', errors='coerce')
tidy_accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81848 entries, 0 to 81847
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID_ENTIDAD  81848 non-null  int64
#  1   ANIO        81848 non-null  int64
#  2   TIPACCID    81848 non-null  category
#  3   CAUSAACCI   81848 non-null  category
#  4   CAPAROD     81848 non-null  category
#  5   CLASACC     81848 non-null  category
#  6   FECHA       81848 non-null  object
#  7   EDAD        81848 non-null  category
# dtypes: category(5), int64(2), object(1)
# memory usage: 2.3+ MB

# %%
# Generamos el dataframe de conservación
tidy_conservacion = pd.read_csv("tidy_conservacion.csv", index_col=False)
tidy_conservacion
# Out:
#       ID_ENTIDAD           ENTIDAD  TOTAL_CONSERVACION  \
# 0              9  CIUDAD DE MEXICO        1.294363e+08
# 1              9  CIUDAD DE MEXICO        1.091483e+08
# 2              9  CIUDAD DE MEXICO        4.997081e+07
# 3              9  CIUDAD DE MEXICO        8.514464e+07
# 4              9  CIUDAD DE MEXICO        2.415727e+07
# ...          ...               ...                 ...
# 1854          32         ZACATECAS        6.094561e+06
# 1855          32         ZACATECAS        5.716601e+06
# 1856          32         ZACATECAS        1.633732e+06
# 1857          32         ZACATECAS        2.625802e+06
# 1858          32         ZACATECAS        2.625802e+06
#
#                                   PROGRAMA_CONSERVACION
# 0                               Estudios y/o Proyectos
# 1     Programa Asociación Público Privada de Conserv...
# 2     Programa Asociación Público Privada de Conserv...
# 3     Programa Asociación Público Privada de Conserv...
# ...

# %%
# Generamos el dataframe de suma estatal
tidy_suma_estatal = pd.read_csv("tidy_suma_estatal.csv", index_col=False)
tidy_suma_estatal
# Out:
#     ID_ENTIDAD  Total_accidentes  TIPACCID_Colisión con objeto fijo  \
# 0            1              1222                                130
# 1            2               489                                 97
# 2            3                93                                  3
# 3            4               559                                 34
# 4            5               466                                 59
# 5            6              1852                                103
# 6            7              2492                                342
# 7            8              3674                                391
# 8            9                 6                                  1
# 9           10              1103                                 90
# 10          11              4074                                354
# 11          12              1699                                184
# 12          13               963                                 66
# ...

# %%
# Generamos el dataframe de suma estatal
tidy_budget = pd.read_csv("budget_transparency.csv", index_col=False)
tidy_budget
# Out:
#      State ID           State  Year  Expenses Type ID          Expenses Type  \
# 0           1  Aguascalientes  2013                 8  Gasto de Obra Pública
# 1           1  Aguascalientes  2014                 8  Gasto de Obra Pública
# 2           1  Aguascalientes  2015                 8  Gasto de Obra Pública
# 3           1  Aguascalientes  2016                 8  Gasto de Obra Pública
# 4           1  Aguascalientes  2017                 8  Gasto de Obra Pública
# ..        ...             ...   ...               ...                    ...
# 283        32       Zacatecas  2017                 8  Gasto de Obra Pública
# 284        32       Zacatecas  2018                 8  Gasto de Obra Pública
# 285        32       Zacatecas  2019                 8  Gasto de Obra Pública
# 286        32       Zacatecas  2020                 8  Gasto de Obra Pública
# 287        32       Zacatecas  2021                 8  Gasto de Obra Pública
#
#      Amount Approved
# 0         1511908040
# ...

# %%
prof = ProfileReport(tidy_suma_estatal)
prof.to_file(output_file='tidy_suma_estatal.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
